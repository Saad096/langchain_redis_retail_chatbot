# %%
import pandas as pd

MAX_TEXT_LENGTH=512

def auto_truncate(val):
    """Truncate the given text."""
    return val[:MAX_TEXT_LENGTH]

# Load Product data and truncate long text fields
all_prods_df = pd.read_csv("product_data.csv", converters={
    'bullet_point': auto_truncate,
    'item_keywords': auto_truncate,
    'item_name': auto_truncate
})

# %%
# Contruct a primary key from item ID and domain name
all_prods_df['primary_key'] = (
    all_prods_df['item_id'] + '-' + all_prods_df['domain_name']
)
# Replace empty strings with None and drop
all_prods_df['item_keywords'].replace('', None, inplace=True)
all_prods_df.dropna(inplace=True)
# all_prods_df

# Reset pandas dataframe index
all_prods_df.reset_index(drop=True, inplace=True)

all_prods_df.head()
# Out:
# /tmp/ipykernel_177101/1781557686.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   all_prods_df['item_keywords'].replace('', None, inplace=True)
#       item_id marketplace country main_image_id domain_name  \
# 0  B07T2JY31Y      Amazon      IN   71vX7qIEAIL   amazon.in
# 1  B0854774X5      Amazon      IN   81xaJCVnl3L   amazon.in
# 2  B085494J1X      Amazon      IN   71iB+TUHVyL   amazon.in
# 3  B08511FPLP      Amazon      IN   81Gd4qnyogL   amazon.in
# 4  B08542LQNW      Amazon      IN   719JbIZ9gqL   amazon.in
#
#                                         bullet_point  \
# 0  3D Printed Hard Back Case Mobile Cover for Son...
# 1  Snug fit for Nokia 8.1, with perfect cut-outs ...
# 2  Snug fit for Lenovo Z6 Pro, with perfect cut-o...
# 3  Snug fit for Samsung Galaxy M31, with perfect ...
# 4  Snug fit for Huawei Y9 (2019), with perfect cu...
#
#                                        item_keywords material  \
# 0  mobile cover back cover mobile case phone case...     Wood
# 1  Back Cover Designer Case Designer Take It Easy...  Silicon
# 2  Back Cover Designer Case Designer Panda Textur...  Silicon
# 3  Samsung Galaxy M31 mobile case Samsung Galaxy ...  Plastic
# 4  Back Cover Designer Case Designer Happy Mobile...  Silicon
#
#                    brand       color  \
# 0  Amazon Brand - Solimo      others
# 1  Amazon Brand - Solimo  Multicolor
# 2  Amazon Brand - Solimo  Multicolor
# 3  Amazon Brand - Solimo  Multicolor
# 4  Amazon Brand - Solimo  Multicolor
#
#                                            item_name           model_name  \
# 0  Amazon Brand - Solimo Designer Leaf on Wood 3D...  Sony Xperia Z1 L39H
# 1  Amazon Brand - Solimo Designer Take It Easy UV...            Nokia 8.1
# 2  Amazon Brand - Solimo Designer Panda Texture U...        Lenovo Z6 Pro
# 3  Amazon Brand - Solimo Designer Old Stambh 3D P...   Samsung Galaxy M31
# 4  Amazon Brand - Solimo Designer Happy UV Printe...     Huawei Y9 (2019)
#
#       model_number         product_type           primary_key
# 0   gz8056-SL40528  CELLULAR_PHONE_CASE  B07T2JY31Y-amazon.in
# 1  UV10714-SL40617  CELLULAR_PHONE_CASE  B0854774X5-amazon.in
# 2  UV10833-SL40408  CELLULAR_PHONE_CASE  B085494J1X-amazon.in
# 3   gz8759-SL40523  CELLULAR_PHONE_CASE  B08511FPLP-amazon.in
# 4  UV10721-SL13243  CELLULAR_PHONE_CASE  B08542LQNW-amazon.in

# %%
# Num products to use (subset)
NUMBER_PRODUCTS = 2500  

# Get the first 1000 products with non-empty item keywords
product_metadata = ( 
    all_prods_df
     .head(NUMBER_PRODUCTS)
     .to_dict(orient='index')
)

# %%
# Check one of the products
product_metadata[0]
# Out:
# {'item_id': 'B07T2JY31Y',
#  'marketplace': 'Amazon',
#  'country': 'IN',
#  'main_image_id': '71vX7qIEAIL',
#  'domain_name': 'amazon.in',
#  'bullet_point': '3D Printed Hard Back Case Mobile Cover for Sony Xperia Z1 L39H Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports. Stylish design and appearance, express your unique personality. Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface. Slim Hard Back Cover No Warranty',
#  'item_keywords': 'mobile cover back cover mobile case phone case mobile panel phone panel LG mobile case LG phone cover LG back case hard case 3D printed mobile cover mobile cover back cover mobile case phone case mobile panel phone panel Sony Xperia mobile case Sony Xperia phone cover Sony Xperia back case hard case 3D printed mobile cover mobile cover back cover mobile case phone case mobile panel phone panel Sony Xperia mobile case Sony Xperia phone cover Sony Xperia back case hard case 3D printed mobile cover mobile cove',
#  'material': 'Wood',
#  'brand': 'Amazon Brand - Solimo',
#  'color': 'others',
#  'item_name': 'Amazon Brand - Solimo Designer Leaf on Wood 3D Printed Hard Back Case Mobile Cover for Sony Xperia Z1 L39H',
#  'model_name': 'Sony Xperia Z1 L39H',
#  'model_number': 'gz8056-SL40528',
#  'product_type': 'CELLULAR_PHONE_CASE',
#  'primary_key': 'B07T2JY31Y-amazon.in'}

# %%
# from langchain.embeddings import OpenAIEmbeddings
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores.redis import Redis as RedisVectorStore
from langchain_core.callbacks.manager import CallbackManager

# data that will be embedded and converted to vectors
texts = [
    v['item_name'] for k, v in product_metadata.items()
]

# product metadata that we'll store along our vectors
metadatas = list(product_metadata.values())

# we will use OpenAI as our embeddings provider
embedding = OpenAIEmbeddings(openai_api_key="open-key", model="text-embedding-3-small")

# name of the Redis search index to create
index_name = "products"

# assumes you have a redis stack server running on within your docker compose network
redis_url = "redis://redis:6379"

# create and load redis with documents
vectorstore = RedisVectorStore.from_texts(
    texts=texts,
    metadatas=metadatas,
    embedding=embedding,
    index_name=index_name,
    redis_url=redis_url
)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/redis/connection.py:698, in AbstractConnection.connect(self)
#     697 try:
# --> 698     sock = self.retry.call_with_retry(
#     699         lambda: self._connect(), lambda error: self.disconnect(error)
#     700     )
#     701 except socket.timeout:
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/redis/retry.py:46, in Retry.call_with_retry(self, do, fail)
#      45 try:
# ---> 46     return do()
#      47 except self._supported_errors as error:
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/redis/connection.py:699, in AbstractConnection.connect.<locals>.<lambda>()
#     697 try:
#     698     sock = self.retry.call_with_retry(
# --> 699         lambda: self._connect(), lambda error: self.disconnect(error)
#     700     )
#     701 except socket.timeout:
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/redis/connection.py:955, in Connection._connect(self)
#     954 err = None
# --> 955 for res in socket.getaddrinfo(
#     956     self.host, self.port, self.socket_type, socket.SOCK_STREAM
#     957 ):
#     958     family, socktype, proto, canonname, socket_address = res
#
# File /usr/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[7], line 24
#      21 redis_url = "redis://redis:6379"
#      23 # create and load redis with documents
# ---> 24 vectorstore = RedisVectorStore.from_texts(
#      25     texts=texts,
#      26     metadatas=metadatas,
#      27     embedding=embedding,
#      28     index_name=index_name,
#      29     redis_url=redis_url
#      30 )
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/langchain_community/vectorstores/redis/base.py:491, in Redis.from_texts(cls, texts, embedding, metadatas, index_name, index_schema, vector_schema, **kwargs)
#     426 @classmethod
#     427 def from_texts(
#     428     cls: Type[Redis],
#    (...)
#     435     **kwargs: Any,
#     436 ) -> Redis:
#     437     """Create a Redis vectorstore from a list of texts.
#     438
#     439     This is a user-friendly interface that:
#    (...)
#     489         ImportError: If the redis python package is not installed.
#     490     """
# --> 491     instance, _ = cls.from_texts_return_keys(
#     492         texts,
#     493         embedding,
#     494         metadatas=metadatas,
#     495         index_name=index_name,
#     496         index_schema=index_schema,
#     497         vector_schema=vector_schema,
#     498         **kwargs,
#     499     )
#     500     return instance
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/langchain_community/vectorstores/redis/base.py:413, in Redis.from_texts_return_keys(cls, texts, embedding, metadatas, index_name, index_schema, vector_schema, **kwargs)
#     409         index_schema = generated_schema
#     411 # Create instance
#     412 # init the class -- if Redis is unavailable, will throw exception
# --> 413 instance = cls(
#     414     redis_url,
#     415     index_name,
#     416     embedding,
#     417     index_schema=index_schema,
#     418     vector_schema=vector_schema,
#     419     **kwargs,
#     420 )
#     422 # Add data to Redis
#     423 keys = instance.add_texts(texts, metadatas, keys=keys)
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/langchain_community/vectorstores/redis/base.py:276, in Redis.__init__(self, redis_url, index_name, embedding, index_schema, vector_schema, relevance_score_fn, key_prefix, **kwargs)
#     274     redis_client = get_client(redis_url=redis_url, **kwargs)
#     275     # check if redis has redisearch module installed
# --> 276     check_redis_module_exist(redis_client, REDIS_REQUIRED_MODULES)
#     277 except ValueError as e:
#     278     raise ValueError(f"Redis failed to connect: {e}")
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/langchain_community/utilities/redis.py:55, in check_redis_module_exist(client, required_modules)
#      53 def check_redis_module_exist(client: RedisType, required_modules: List[dict]) -> None:
#      54     """Check if the correct Redis modules are installed."""
# ---> 55     installed_modules = client.module_list()
#      56     installed_modules = {
#      57         module[b"name"].decode("utf-8"): module for module in installed_modules
#      58     }
#      59     for module in required_modules:
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/redis/commands/core.py:5761, in ModuleCommands.module_list(self)
#    5754 def module_list(self) -> ResponseT:
#    5755     """
#    5756     Returns a list of dictionaries containing the name and version of
#    5757     all loaded modules.
#    5758
#    5759     For more information see https://redis.io/commands/module-list
#    5760     """
# -> 5761     return self.execute_command("MODULE LIST")
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/redis/client.py:1255, in Redis.execute_command(self, *args, **options)
#    1253 pool = self.connection_pool
#    1254 command_name = args[0]
# -> 1255 conn = self.connection or pool.get_connection(command_name, **options)
#    1257 try:
#    1258     return conn.retry.call_with_retry(
#    1259         lambda: self._send_command_parse_response(
#    1260             conn, command_name, *args, **options
#    1261         ),
#    1262         lambda error: self._disconnect_raise(conn, error),
#    1263     )
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/redis/connection.py:1441, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1437     self._in_use_connections.add(connection)
#    1439 try:
#    1440     # ensure this connection is connected to Redis
# -> 1441     connection.connect()
#    1442     # connections that the pool provides should be ready to send
#    1443     # a command. if not, the connection was either returned to the
#    1444     # pool before all data has been read or the socket has been
#    1445     # closed. either way, reconnect and verify everything is good.
#    1446     try:
#
# File ~/Documents/Ibex_workspace/new_bot/langchain-retail-chatbot/.retail_bot/lib/python3.10/site-packages/redis/connection.py:704, in AbstractConnection.connect(self)
#     702     raise TimeoutError("Timeout connecting to server")
#     703 except OSError as e:
# --> 704     raise ConnectionError(self._error_message(e))
#     706 self._sock = sock
#     707 try:
#
# ConnectionError: Error -3 connecting to redis:6379. Temporary failure in name resolution.
